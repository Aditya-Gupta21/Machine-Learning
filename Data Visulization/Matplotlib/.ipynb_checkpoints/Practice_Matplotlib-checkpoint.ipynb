# %%
#  Import the library of the python 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#  Creating the first array 
x = np.random.randint(5)
x
# Out:
# array([5, 8, 7, 7, 1], dtype=int32)
